# %%
import camelot as cl

# %%
tables = cl.read_pdf('Status Codes.pdf', pages='1')
print(tables)
# Out:
# <TableList n=1>

# %%
tables.export('Status Codes.csv', f='csv', compress=True)
tables[0].to_csv('Status Codes.csv')
